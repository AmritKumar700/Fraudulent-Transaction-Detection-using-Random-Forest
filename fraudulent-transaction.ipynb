# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Data Collections

# %%
# Collections Data in CSV Format By Using Pandas
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# # Data Preparation & Cleaning

# %%
# Checking NAN in Dataset
data.isnull()
# Out:
#          Time     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 284802  False  False  False  False  False  False  False  False  False  False
# 284803  False  False  False  False  False  False  False  False  False  False
# 284804  False  False  False  False  False  False  False  False  False  False
# 284805  False  False  False  False  False  False  False  False  False  False
# 284806  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Summary about the dataset, mean, mode, std, max, min some statistical
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.759061e-12 -8.251130e-13 -9.654937e-13  8.321385e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.649999e-13  4.248366e-13 -3.054600e-13  8.777971e-14 -1.179749e-12
# ...

# %%
# Summary statistical Transpose
data.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.759061e-12      1.958696  -56.407510     -0.920373
# V2      284807.0 -8.251130e-13      1.651309  -72.715728     -0.598550
# V3      284807.0 -9.654937e-13      1.516255  -48.325589     -0.890365
# V4      284807.0  8.321385e-13      1.415869   -5.683171     -0.848640
# V5      284807.0  1.649999e-13      1.380247 -113.743307     -0.691597
# V6      284807.0  4.248366e-13      1.332271  -26.160506     -0.768296
# V7      284807.0 -3.054600e-13      1.237094  -43.557242     -0.554076
# V8      284807.0  8.777971e-14      1.194353  -73.216718     -0.208630
# V9      284807.0 -1.179749e-12      1.098632  -13.434066     -0.643098
# V10     284807.0  7.092545e-13      1.088850  -24.588262     -0.535426
# V11     284807.0  1.874948e-12      1.020713   -4.797473     -0.762494
# ...

# %% [markdown]
# # EDA

# %%
# Checking Graphical form of Time, how transaction show according to time
df['Time'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# Checking Graphical form of Amount in kDE PLot
df['Amount'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# Checking the lenght of trasaction without fraud in Data set
len(data[data['Class'] == 0])
# Out:
# 284315

# %%
# Checking the lenght of trasaction with fraud in Data set
len(data[data['Class'] == 1])
# Out:
# 492

# %%
print('Transaction without fraud', len(df[df['Class'] == 0]))
print('Transaction with fraud', len(df[df['Class'] == 1]))
# Out:
# Transaction without fraud 284315
# Transaction with fraud 492

# %%
# Not Fraud Case
notfraud = df[df['Class'] == 0]

# %%
# Fraud Case
fraud = df[df['Class'] == 1]

# %%
# Now, we can see graphical form of Without fraud trnsaction, and fraud transaction with time and amount

import matplotlib.pyplot as plt
f, (ax1, ax2) = plt.subplots(2, 1, sharex = True, figsize = (10, 8))

# Title
f.suptitle('Time of Transaction vs Amount by Class', fontsize = 16)

# Scatter plot for fraud transactions
ax1.scatter(fraud['Time'], fraud['Amount'], alpha = 0.5)
ax1.set_title('With Fraud Transactions')
ax1.set_ylabel('Amount')


# Scatter plot for not fraud transactions
ax2.scatter(notfraud['Time'], notfraud['Amount'], alpha = 0.5)
ax2.set_title('Without Fraud Transactions')
ax2.set_xlabel('Time')
ax2.set_ylabel('Amount')

plt.show()

# %%
# Now checking correlation between features
df.corr().plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Model Selection & Training

# %%
y = df['Class']

# %%
x = df.drop(columns = ['Class'], axis = 1)

# %%
x
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
# selection of model
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
# Divide dataset into training and testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
rfc = RandomForestClassifier(n_estimators = 20, criterion = 'entropy', random_state = 32, max_depth = 10)

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=10, n_estimators=20,
#                        random_state=32)

# %% [markdown]
# # Model Evaluation | Prediction & Interpretation

# %%
# Testing our model, and predict 
y_pred = rfc.predict(x_test)

# %%
from sklearn.metrics import  classification_report, confusion_matrix

# %% [markdown]
# The classification_report (from sklearn.metrics) gives you a detailed summary of how well your classification model performed:

# %%
print('Classifcation report \n', classification_report(y_test, y_pred))
# Out:
# Classifcation report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.95      0.76      0.84        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.88      0.92     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
conf_mat = confusion_matrix(y_true = y_test, y_pred = y_pred)
print('Confusion matrix:\n', conf_mat)
# Out:
# Confusion matrix:
#  [[56860     4]
#  [   24    74]]

# %%
# Checking the accuracy of our model, how well our model performe
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9995084442259752

# %% [markdown]
# Trying with undersmapling technique - This is the pipeline module we need from imblearn for Undersampling

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %%
rand_sampling = RandomUnderSampler()
model = RandomForestClassifier(n_estimators = 30,criterion = 'entropy', random_state = 32, max_depth = 10)

# %%
# Define the pipeline and combine sampling method with the RF model
pipeline = Pipeline([('RandomUnderSampler', rand_sampling), ('RF', model)])

# %%
pipeline.fit(x_train, y_train) 
pred = pipeline.predict(x_test)

# %%
# Result from the classification report and confusion matrix 
print('Classifcation report: ', classification_report(y_test, pred))
conf_mat = confusion_matrix(y_true = y_test, y_pred = pred)
print('Confusion matriX: ', conf_mat)
# Out:
# Classifcation report:                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.06      0.93      0.12        98
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.95      0.55     56962
# weighted avg       1.00      0.98      0.99     56962
#
# Confusion matriX:  [[55510  1354]
#  [    7    91]]

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9995084442259752
